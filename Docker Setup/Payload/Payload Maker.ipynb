# %%
import random
import pandas as pd
import numpy as np
import json
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import joblib

# %% [markdown]
# ## Only Need To Change The <u>"User Profile"</u> To Change The Payload

# %%
# Define the base path for the food categories directory
base_path = './Dependencies/'
profile = pd.read_csv(f"{base_path}User Profile.csv")

# %%
# Load existing user profiles
user_profiles = profile

foods_path = f'{base_path}Categories/'
# Define the file names with their corresponding categories
file_names = {
    'Cereals': '1. Cereal and Cereal Products.xlsx',
    'Legumes': '2. Legumes.xlsx',
    'Vegetables': '3. Vegetables.xlsx',
    'Fruits': '4. Fruits.xlsx',
    'Nuts and Dry Fruits': '5. Nuts and Dry Fruits.xlsx',
    'Dairy Products': '6. Dairy Products.xlsx',
    'Meat and Meat Products': '7. Meat and Meat Products.xlsx',
    'Fish': '8. Fish.xlsx',
    'Eggs': '9. Eggs.xlsx',
    'Sugars and Sweets': '10. Sugar - Sweets and Beverages.xlsx',
    'Dishes': '11. Dishes.xlsx'
}

# Load all files into a dictionary of DataFrames using the base path and file names
food_data = {category: pd.read_excel(foods_path + filename) for category, filename in file_names.items()}

# Function to assign reaction (0-5)
def get_reaction():
    return random.randint(0, 5)

# Functions to calculate impacts for fasting sugar
def age_impact_fasting(age):
    if age <= 40:
        return 1.0
    elif age <= 60:
        return 1.0 + (age - 40) * 0.01  # Increase by 1% per year above 40
    else:
        return 1.20 + (age - 60) * 0.015  # Further increase by 1.5% per year above 60

def bmi_impact_fasting(bmi):
    if bmi < 18.5:
        return 0.90  # Decrease by 10% for underweight
    elif bmi < 25:
        return 1.0  # No impact for normal weight
    elif bmi < 30:
        return 1.10 + (bmi - 25) * 0.02  # Increase by 2% for each unit of BMI above 25
    else:
        return 1.20 + (bmi - 30) * 0.025  # Further increase by 2.5% for each unit of BMI above 30

def hba1c_impact_fasting(hba1c):
    if hba1c < 5.7:
        return 1.0
    elif hba1c < 6.5:
        return 1.0 + (hba1c - 5.7) * 0.10  # Increase by 10% per unit above 5.7
    else:
        return 1.20 + (hba1c - 6.5) * 0.20  # Further increase by 20% per unit above 6.5

# Functions to calculate impacts for 2-hour post-meal sugar
def age_impact_post_meal(age):
    if age <= 40:
        return 1.0
    elif age <= 60:
        return 1.0 + (age - 40) * 0.15  # Increase by 15% per year above 40
    else:
        return 1.30 + (age - 60) * 0.20  # Further increase by 20% per year above 60

def bmi_impact_post_meal(bmi):
    if bmi < 18.5:
        return 0.90  # Decrease by 10% for underweight
    elif bmi < 25:
        return 1.0  # No impact for normal weight
    elif bmi < 30:
        return 1.15 + (bmi - 25) * 0.03  # Increase by 3% for each unit of BMI above 25
    else:
        return 1.30 + (bmi - 30) * 0.05  # Further increase by 5% for each unit of BMI above 30

def hba1c_impact_post_meal(hba1c):
    if hba1c < 5.7:
        return 1.0
    elif hba1c < 6.5:
        return 1.0 + (hba1c - 5.7) * 0.30  # Increase by 30% per unit above 5.7
    else:
        return 1.30 + (hba1c - 6.5) * 0.50  # Further increase by 50% per unit above 6.5

# Function to calculate gender impact
def gender_impact(gender):
    return 0.95 if gender == 'Female' else 1.0  # Decrease by 5% for females

# Function to calculate fasting blood sugar level
def calculate_fasting_sugar(hba1c, age, bmi, gender):
    baseline_fbs = 90  # Baseline fasting blood sugar level for normal range
    if hba1c >= 5.7:  # Adjust baseline for diabetic range
        baseline_fbs = 100
    total_impact_factor = age_impact_fasting(age) * bmi_impact_fasting(bmi) * hba1c_impact_fasting(hba1c) * gender_impact(gender)
    adjusted_fbs = baseline_fbs * total_impact_factor
    return adjusted_fbs

# Function to calculate 2-hour post-meal blood sugar level
def calculate_post_meal_sugar(fasting_sugar, gl, age, bmi, hba1c, gender, strictness=0.1):
    base_glycemic_response = 1.5  # Increased base response for more significant impact
    total_impact_factor = age_impact_post_meal(age) * bmi_impact_post_meal(bmi) * hba1c_impact_post_meal(hba1c) * gender_impact(gender)
    adjusted_glycemic_response = base_glycemic_response * total_impact_factor
    initial_increase = gl * adjusted_glycemic_response
    increase_after_2_hours = initial_increase * 0.70  # Applying 30% decay factor for 2 hours
    post_meal_sugar = fasting_sugar + increase_after_2_hours

    # Limiting the post-meal sugar value
    max_pms = 350  # Threshold for the post-meal sugar level
    if post_meal_sugar > max_pms:
        excess = post_meal_sugar - max_pms
        limited_excess = max_pms / (1 + np.exp(strictness * (excess - max_pms / 2)))
        post_meal_sugar = max_pms + limited_excess

    return post_meal_sugar

# Function to generate a profile
def create_profile(user, food_df):
    profiles = []
    for _, food in food_df.iterrows():
        fasting_sugar = round(calculate_fasting_sugar(user['HbA1c Level'], user['Age'], user['BMI'], user['Gender']))
        reaction = get_reaction()
        post_meal_sugar = round(calculate_post_meal_sugar(fasting_sugar, food['GL'], user['Age'], user['BMI'], user['HbA1c Level'], user['Gender']))
        
        profile = {
            'Age': user['Age'],
            'Gender': user['Gender'],
            'BMI': user['BMI'],
            'HbA1c Level': user['HbA1c Level'],
            'Food': food['Food'],
            'GL': food['GL'],
            'Reaction': reaction,
            'FBS': fasting_sugar,
            'PMS': post_meal_sugar
        }
        profiles.append(profile)
    return profiles

# Function to sample user profiles based on HbA1c distribution
def sample_user_profiles(user_profiles, proportion_above_prediabetes=0.75):
    n_total = len(user_profiles)
    n_above_prediabetes = int(n_total * proportion_above_prediabetes)
    n_normal = n_total - n_above_prediabetes

    above_prediabetes_profiles = user_profiles[user_profiles['HbA1c Level'] >= 5.7]
    normal_profiles = user_profiles[user_profiles['HbA1c Level'] < 5.7]

    sampled_above_prediabetes = above_prediabetes_profiles.sample(n=min(n_above_prediabetes, len(above_prediabetes_profiles)), random_state=42)
    sampled_normal = normal_profiles.sample(n=min(n_normal, len(normal_profiles)), random_state=42)

    sampled_profiles = pd.concat([sampled_above_prediabetes, sampled_normal])
    return sampled_profiles

# Function to generate datasets for each category and compile them into a dictionary of DataFrames
def generate_datasets_by_category(user_profiles):
    category_datasets = {}
    for category, food_df in food_data.items():
        all_data = []
        for _, user in user_profiles.iterrows():
            user_data = create_profile(user, food_df)
            all_data.extend(user_data)
        category_datasets[category] = pd.DataFrame(all_data)
    return category_datasets

# Generate dataset
datasets_by_category = generate_datasets_by_category(user_profiles)

# Display the first few rows of the dataset
display(datasets_by_category['Dishes'].head(50))
# Out:
#     Age Gender   BMI  HbA1c Level                      Food  GL  Reaction  \
# 0    32   Male  26.0          7.1                   Kitchri  31         3
# 1    32   Male  26.0          7.1                Rice Kheer  29         0
# 2    32   Male  26.0          7.1                    Feerni  32         3
# 3    32   Male  26.0          7.1               Wheat Dalia  28         5
# 4    32   Male  26.0          7.1              Banana Kheer  21         5
# 5    32   Male  26.0          7.1                   Chapati  30         2
# 6    32   Male  26.0          7.1          Daal Masur Curry  12         4
# 7    32   Male  26.0          7.1  Kidney Bean Curry Kalool  10         1
# 8    32   Male  26.0          7.1                 Alu Gosht  15         3
# 9    32   Male  26.0          7.1                     Kofta   5         4
# 10   32   Male  26.0          7.1               Pulao Gosht  18         1
# 11   32   Male  26.0          7.1              Chapal Kabab   3         5
# 12   32   Male  26.0          7.1               Shami Kabab   2         1
# 13   32   Male  26.0          7.1             Chicken Curry   4         3
# 14   32   Male  26.0          7.1                    Haleem   9         0
# 15   32   Male  26.0          7.1                     Sajji   0         3
# 16   32   Male  26.0          7.1         Machli Fried Fish   0         0
# 17   32   Male  26.0          7.1                   Biryani  29         1
# 18   32   Male  26.0          7.1                Halwa Suji  40         2
# 19   32   Male  26.0          7.1        Rice Pudding Kheer  29         1
# 20   32   Male  26.0          7.1                     Zarda  45         3
# 21   32   Male  26.0          7.1              Halwa Gajjar  34         5
#
#     FBS  PMS
# 0   148  209
# 1   148  205
# 2   148  211
# 3   148  204
# 4   148  190
# 5   148  207
# 6   148  172
# 7   148  168
# 8   148  178
# 9   148  158
# 10  148  184
# 11  148  154
# 12  148  152
# 13  148  156
# 14  148  166
# 15  148  148
# 16  148  148
# 17  148  205
# 18  148  227
# 19  148  205
# 20  148  237
# 21  148  215

# %%
import json

# Dictionary to hold all category data
all_categories_data = {}

# Loop through each category and convert DataFrame to JSON
for category, df in datasets_by_category.items():
    # Convert the DataFrame to a list of dicts
    category_data = df.to_dict(orient='records')
    
    # Add this category's data to the all_categories_data dictionary
    all_categories_data[category] = category_data

# Convert the combined dictionary to a JSON string
combined_json = json.dumps(all_categories_data, indent=4)

# Optionally, save this combined JSON data to a file
with open('./Outputs/Payload.json', 'w') as file:
    file.write(combined_json)

# Print a sample to verify (printing the first 500 characters of the JSON string)
print("Combined JSON data:")
print(combined_json)
# Out:
# Combined JSON data:
# {
#     "Cereals": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Barley Whole grain flour",
#             "GL": 21.78,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 191
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Corn Whole grain flour",
#             "GL": 49.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 245
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Corn Flakes",
#             "GL": 65.238,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 277
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Corn Bread",
#             "GL": 26.772,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 201
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Millet Pearl Whole grain flour",
#             "GL": 48.3,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 244
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Oat Whole grain flour",
#             "GL": 15.8,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 179
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rye Whole grain flour",
#             "GL": 31.995,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 211
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Polished",
#             "GL": 57.743,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 262
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Polished Boiled",
#             "GL": 21.024,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 190
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Polished Fried",
#             "GL": 18.535,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 185
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Flakes",
#             "GL": 61.76,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 270
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sorghum whole grain flour",
#             "GL": 53.8371574,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 255
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sorghum Bread",
#             "GL": 40.896,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 229
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Vermicelli",
#             "GL": 26.11,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 200
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Whole grain flour",
#             "GL": 42.056,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 231
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat flour refined",
#             "GL": 58.2709468,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 264
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat flour granular",
#             "GL": 65.705,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 278
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Bread Nan",
#             "GL": 53.605,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 254
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Bread Chapati",
#             "GL": 35.34,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 218
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Bread Paratha",
#             "GL": 12.736,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 173
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Bread Puri",
#             "GL": 25.251,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 198
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Bread Double Roti",
#             "GL": 38.908,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 225
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Flour Biscuit",
#             "GL": 51.59,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 250
#         }
#     ],
#     "Legumes": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Braod Bean Raw Lobia",
#             "GL": 33.516,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 214
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Braod Bean Raw Lobia Cooked",
#             "GL": 16.511,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 181
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chickpea Channa ",
#             "GL": 20.031,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 188
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chickpea Channa Cooked",
#             "GL": 8.064,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 164
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cow Pea Raw Rawan",
#             "GL": 38.29654,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 224
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cow Pea Raw Rawan Cooked",
#             "GL": 10.353,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 169
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kidney Bean Raw",
#             "GL": 14.304,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 176
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kidney Bean Raw Cooked",
#             "GL": 6.168,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lentil Raw",
#             "GL": 19.104,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 186
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lentil Cooked",
#             "GL": 5.312,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 159
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mung Bean Raw",
#             "GL": 17.075,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 182
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mung Bean Cooked",
#             "GL": 6.084,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mash Bean Raw",
#             "GL": 26.746,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 201
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mash Bean Cooked",
#             "GL": 5.625,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 159
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pigeon Pea Raw Arhar",
#             "GL": 19.38,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 186
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pigeon Pea Cooked Arhar",
#             "GL": 9.405,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 167
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pea Garden Raw Mattar",
#             "GL": 12.804,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 173
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pea Garden Cooked Mattar",
#             "GL": 7.752,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 163
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "SoyBean Seed",
#             "GL": 4.624,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 157
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sunflower Seed",
#             "GL": 7.326,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 163
#         }
#     ],
#     "Vegetables": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Bath Sponge Tori",
#             "GL": 0.64,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Bottle Gourd Kaddu",
#             "GL": 0.54,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Bitter Gourd Karela",
#             "GL": 0.792,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 150
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Bringal Baingan",
#             "GL": 0.58,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cauliflower Phool Gobi",
#             "GL": 0.672,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cucumber Khira",
#             "GL": 0.48,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cabbage",
#             "GL": 0.48,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kulfa Sag kulfa",
#             "GL": 2.006,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lady finger Bhindi",
#             "GL": 1.58,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 151
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lettuce",
#             "GL": 0.465,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mountain ebony Kutchnar",
#             "GL": 6.002451,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mustard Leaves Sarson Sag",
#             "GL": 9.125,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 166
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Moongra ",
#             "GL": 0.69,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mint Leaves Podina",
#             "GL": 1.914,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mushroom Khumbi",
#             "GL": 0.33,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pepper Sweet Mirch",
#             "GL": 0.72,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pepper Hot Surkh Mirch",
#             "GL": 4.185,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pumpkin Halva Kadu",
#             "GL": 7.725,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 163
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Spinach Palak",
#             "GL": 0.63,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Tomato ",
#             "GL": 0.656,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Tinda",
#             "GL": 0.54,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 149
#         }
#     ],
#     "Fruits": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Apple",
#             "GL": 5.421,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 159
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Apricot",
#             "GL": 4.25,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Banana Ripe",
#             "GL": 12.272,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 172
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Black Berry",
#             "GL": 3.25,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Dates Dried",
#             "GL": 30.92,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 209
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Dates Fresh",
#             "GL": 13.904,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 176
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fig Fresh",
#             "GL": 6.055,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Grapes",
#             "GL": 6.966,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 162
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Grapes",
#             "GL": 7.158,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 162
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Guava Whole",
#             "GL": 1.989,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Jaman",
#             "GL": 3.325,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 155
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lemon",
#             "GL": 1.7,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 151
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lichi",
#             "GL": 7.65,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 163
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lime",
#             "GL": 3.1789894,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lime Sweet",
#             "GL": 3.499168,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 155
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Loquat",
#             "GL": 3.132,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mango",
#             "GL": 7.905,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 164
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Melon Musk ",
#             "GL": 3.51,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 155
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Melon Water",
#             "GL": 3.96,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mulbery Black Shehtut",
#             "GL": 3.85,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mandarin Kinno",
#             "GL": 3.48,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 155
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mandarin Narangi",
#             "GL": 4.7,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 157
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Orange Sweet Malta",
#             "GL": 4.0,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Peach",
#             "GL": 5.2141662,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 158
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pear",
#             "GL": 4.02,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Persimmon Amlok",
#             "GL": 8.5,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 165
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pineapple",
#             "GL": 5.61,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 159
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Plum",
#             "GL": 6.2709052,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pomegranate",
#             "GL": 3.28,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 155
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Papaya Ripe",
#             "GL": 6.72,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 161
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Phalsa",
#             "GL": 0.95586,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 150
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Strawberry",
#             "GL": 3.198,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Zizyphus Desi Ber",
#             "GL": 4.48,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 157
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Zizyphus Sova Ber",
#             "GL": 3.213,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 154
#         }
#     ],
#     "Nuts and Dry Fruits": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Almond",
#             "GL": 2.895,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Anise",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Walnut",
#             "GL": 1.98,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Peanut Roasted",
#             "GL": 9.226,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 166
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cashew Nut",
#             "GL": 7.1,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 162
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Coconut",
#             "GL": 6.888,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 162
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chilghoza raosted",
#             "GL": 5.28,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 158
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pistachio",
#             "GL": 2.115,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Poppy Seed",
#             "GL": 26.88,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 201
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Peanut",
#             "GL": 3.234,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sesame Saeed",
#             "GL": 5.95,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 160
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Raisin",
#             "GL": 50.886,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 249
#         }
#     ],
#     "Dairy Products": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Butter Milk Lassi",
#             "GL": 0.21,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Curd Dahi",
#             "GL": 1.485,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 151
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cheese",
#             "GL": 1.596,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 151
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cream Balai",
#             "GL": 0.726,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Buffalo Fluid Whole",
#             "GL": 2.64,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 153
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Cow Fluid Whole",
#             "GL": 3.128,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Goat Fluid Whole",
#             "GL": 1.775,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Human Fluid Whole",
#             "GL": 2.952,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Cow Dried Skimmed",
#             "GL": 16.64,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 181
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Milk Cow Dried Whole",
#             "GL": 17.484,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 183
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Yogurt",
#             "GL": 0.742,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 149
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Ice Cream",
#             "GL": 13.42,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 175
#         }
#     ],
#     "Meat and Meat Products": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Beef",
#             "GL": 0.0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Beef Liver",
#             "GL": 2.65,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 153
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Beef Kidney",
#             "GL": 0.003,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Beef heart",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Buffalo Meat",
#             "GL": 0.0,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken Meat",
#             "GL": 0.0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Duck Meat",
#             "GL": 0.0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Goat Meat",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Goat Liver",
#             "GL": 0.0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Goat Kidney",
#             "GL": 0.0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Goat Heart",
#             "GL": 0.0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sheep Meat",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pigeon Meat",
#             "GL": 0.0,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Crab",
#             "GL": 0.07,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         }
#     ],
#     "Fish": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Roa",
#             "GL": 0.058,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Promfret",
#             "GL": 0.0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Khaga",
#             "GL": 0.0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Shanghara",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Soal",
#             "GL": 0.0,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Fish Surmai",
#             "GL": 0.036,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lobster",
#             "GL": 0.0009,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Prawn",
#             "GL": 0.0,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Shrimp",
#             "GL": 0.0,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 148
#         }
#     ],
#     "Eggs": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken egg white Raw",
#             "GL": 0,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken egg Yolk Raw",
#             "GL": 0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken egg Whole Raw",
#             "GL": 0,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken egg Boiled",
#             "GL": 0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Duck egg White Raw",
#             "GL": 0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Duck egg Yolk Raw",
#             "GL": 0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Duck egg Whole Raw",
#             "GL": 0,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Duck egg Boiled",
#             "GL": 0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         }
#     ],
#     "Sugars and Sweets": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sugar White",
#             "GL": 64.675,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 276
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sugar Brown",
#             "GL": 67.06,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 281
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Gur",
#             "GL": 76.0444,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 299
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Honey",
#             "GL": 47.27,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 242
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Barfi",
#             "GL": 55.32,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 258
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Jaleebe",
#             "GL": 60.805808,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 269
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Koa Whole Buffalo Milk",
#             "GL": 5.1573288,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 158
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Halwa Sohen",
#             "GL": 39.676,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 227
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Carbonated: Pepsi, Coke, 7Up",
#             "GL": 5.684,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 159
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Lemon Juice",
#             "GL": 2.0,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Mango Juice",
#             "GL": 6.528,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 161
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Cofee Instant Dry Powder",
#             "GL": 0.0,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Black Tea Leaves Dried",
#             "GL": 0.0,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Green Tea Leaves Dried",
#             "GL": 41.159,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 230
#         }
#     ],
#     "Dishes": [
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kitchri",
#             "GL": 31,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 209
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Kheer",
#             "GL": 29,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 205
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Feerni",
#             "GL": 32,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 211
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Wheat Dalia",
#             "GL": 28,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 204
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Banana Kheer",
#             "GL": 21,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 190
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chapati",
#             "GL": 30,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 207
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Daal Masur Curry",
#             "GL": 12,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 172
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kidney Bean Curry Kalool",
#             "GL": 10,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 168
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Alu Gosht",
#             "GL": 15,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 178
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Kofta",
#             "GL": 5,
#             "Reaction": 4,
#             "FBS": 148,
#             "PMS": 158
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Pulao Gosht",
#             "GL": 18,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 184
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chapal Kabab",
#             "GL": 3,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 154
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Shami Kabab",
#             "GL": 2,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 152
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Chicken Curry",
#             "GL": 4,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 156
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Haleem",
#             "GL": 9,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 166
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Sajji",
#             "GL": 0,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Machli Fried Fish",
#             "GL": 0,
#             "Reaction": 0,
#             "FBS": 148,
#             "PMS": 148
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Biryani",
#             "GL": 29,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 205
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Halwa Suji",
#             "GL": 40,
#             "Reaction": 2,
#             "FBS": 148,
#             "PMS": 227
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Rice Pudding Kheer",
#             "GL": 29,
#             "Reaction": 1,
#             "FBS": 148,
#             "PMS": 205
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Zarda",
#             "GL": 45,
#             "Reaction": 3,
#             "FBS": 148,
#             "PMS": 237
#         },
#         {
#             "Age": 32,
#             "Gender": "Male",
#             "BMI": 26.0,
#             "HbA1c Level": 7.1,
#             "Food": "Halwa Gajjar",
#             "GL": 34,
#             "Reaction": 5,
#             "FBS": 148,
#             "PMS": 215
#         }
#     ]
# }
